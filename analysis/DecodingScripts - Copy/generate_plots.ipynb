# %%
import plots
from importlib import reload
reload(plots)
from plots import *
set_style()

# %% [markdown]
# ### Simple Plot

# %%
plot_rmse('../out/data_test_500_10_distance.pkl')

# %% [markdown]
# ### Single Neuron Plots

# %%
plot_contributions('../out/data_test_500_10_distance_custom_split.pkl')

# %%
filenames = ['../out/data_test_500_10_distance.pkl', '../out/data_test_500_10_position.pkl']
plot_top_contributors(filenames, k_percent=1, start_dt=0, end_dt=20)
# Out:
# [6.855394515511976, 7.028311369309213]
# [0.3475587092631812, 0.38272863458969275]

# %%
filename = '../out/data_test_500_10_distance_custom_split.pkl'
plot_rolling_contributions(filename, window_size=4, k_percents=[1, 10, 30])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[55], line 2
#       1 filename = 'out/data_test_500_10_distance_custom_split.pkl'
# ----> 2 plot_rolling_contributions(filename, window_size=4, k_percents=[1, 10, 30])
#
# File ~/Documents/Utveksling/research/Code/Encoding/src/plots.py:154, in plot_rolling_contributions(filename, window_size, k_percents)
#     145 def plot_rolling_contributions(filename, window_size=4, k_percents=[1, 10, 30]):
#     146     """
#     147     Creates a rolling plot of top contributor percentages over time steps.
#     148
#    (...)
#     152         k_percents (list): List of percentages of top contributors to analyze
#     153     """
# --> 154     with open(filename, 'rb') as f:
#     155         data = pickle.load(f)
#     157     models = data['models']
#
# ...
